# %%
#Importamos las librerías necesarias:
import pandas
dataset= pandas.read_excel("genabrev1.xlsx")
import pandas as pd
#Leemos el excel con las abreviaturas de los genes con pandas:
dataset=pd.read_excel("genabrev1.xlsx")
dataset

from bs4 import BeautifulSoup
import requests
import pandas as pd
i = 0
while i < 11:
    genabrev = pd.read_excel("genabrev1.xlsx", sheet_name = i)
      #Convertimos la lectura en una lista:
    gen10 = genabrev["Gen Abrev"].to_list()
    i += 1
    n = 0
    #Realizamos un bucle para obtener todos los urls:
    while n < len(gen10):
        url = "https://www.uniprot.org/uniprot/?query="+ gen10[n] +"+Bos+Taurus&sort=score"  #Se irán pasando cada abreviacion de los 
                                                                                         #genes a traves de los URL  
        n += 1
        html = requests.get(url).text 
        
        soup = BeautifulSoup(html, "lxml")
        #Empezaremos con el scrapeo                #con este codigo buscaremos en el html "noResultsMessage" 
        empty = soup.find("div", {"id" : "noResultsMessage"})
        empty2 = soup_2.find("div", {"id" : "noResultsMessage"})
        #Si no hay resultado de la búsqueda, se harán los siguientes pasos:
        if empty or empty2 is not None: #Esto hará que se impriman espacios en blano en cada columna en caso no existan resultados
            print("")
       #En caso de encontrar resultados en la busqueda se procederá a hacer lo siguiente       
        else:
           
            status = soup_2.find("a", class_="icon-uniprot reviewed-icon tooltipped")  #Buscaremos la clase indicada
            if status is not None:                                                      #En caso de que exista lo pedido 
                print(status.text)             #Para el caso de status colocaremos "unrewieved" en caso no se encuentre lo pedidO
                                               # "reviewed" en caso si se encuentre
# Out:
# Reviewed
#
#
#
#
#
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
#
#
#
# Reviewed
# Reviewed
#
#
# Reviewed
# Reviewed
# Reviewed
#
# Reviewed
#
# Reviewed
# Reviewed
# Reviewed
#
# Reviewed
# Reviewed
# Reviewed
# Reviewed
#
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
#
# Reviewed
#
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
#
# Reviewed
# Reviewed
# Reviewed
# Reviewed
# Reviewed
#
# Reviewed
# ...
